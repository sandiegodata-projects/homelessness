# %%
# %matplotlib inline

import pandas as pd
import geopandas as gpd
import numpy as np
import metapack as mp
import rowgenerators as rg
import publicdata as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(color_codes=True)

# %%
import metapack as mp
pkg = mp.open_package('http://library.metatab.org/arcgis.com-risk-3.zip')

# Create Dataframes
resources_gdf = pkg.resource('resources').geoframe()
county_outline_gdf = pkg.resource('county_outline').geoframe()
shelters_services_gdf = pkg.resource('shelters_services').geoframe()
homeless_population_gdf = pkg.resource('homeless_population').geoframe()
risk_factors_gdf = pkg.resource('risk_factors').geoframe()

# %%
resources_gdf.plot()

# %%
homeless_population_gdf.plot(column='totpeople')

# %%
homeless_population_gdf.head().T
# Out:
#                                                                     0  \
# id                                                                  0
# objectid                                                            1
# tract                                                          101110
# uniqid                                                              1
# totpop_cy                                                        4927
# totunsheltpeople                                                    1
# totsheltpeople                                                      0
# totpeople                                                           1
# poly_area                                                    0.441046
# popdensity                                                    11171.2
# homelesspopdensity                                            2.26734
# unsheltereddensity                                            2.26734
# ...

# %%
homeless_population_gdf.female.hist()
