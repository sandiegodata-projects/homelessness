# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
pkg = mp.jupyter.open_package()
#pkg = mp.jupyter.open_source_package()
pkg
# Out:
# # HUD Point in Time Counts by CoC
# `hudexchange.com-pit-coc-1` Last Update: 2019-07-07T19:23:44
#
# __
#
#
# ## Documentation Links
#
# * [EDA Notebook For pitc_coc](https://github.com/sandiegodata-projects/homelessness/blob/master/datasets/hudexchange.com-pit-coc/notebooks/eda-pitc_coc.ipynb) Jupyter EDA notebook.
# * [PIT and HIC Data Since 2007](https://www.hudexchange.info/resource/3031/pit-and-hic-data-since-2007/)
#
#
#
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
# ## Resources
#
# * ** [pitc_coc](data/pitc_coc.csv)**. Combined pitc, 2007 to 2018
#
# ## References
#
# * **[pitc_coc_2018](https://www.hudexchange.info/resources/documents/2007-2018-PIT-Counts-by-CoC.xlsx#2018)**. 2007 - 2018 PIT Counts by CoC; 2018 workbook
# * **[pitc_coc_2017](https://www.hudexchange.info/resources/documents/2007-2018-PIT-Counts-by-CoC.xlsx#2017)**. 2006 - 2018 PIT Counts by CoC; 2017 workbook
# ...

# %%
df = pkg.resource('pitc_coc').dataframe()
df =df[df.coc_name != 'Total']
df.head().T
# Out:
#                                                        1              2  \
# year                                                2007           2007
# coc_number                                           NaN         AK-500
# coc_name                                             NaN  Anchorage CoC
# coc_category                                         NaN            NaN
# chronically_homeless                                 NaN            NaN
# chronically_homeless_individuals                     NaN            224
# chronically_homeless_people_in_families              NaN            NaN
# homeless_children_of_parenting_youth                 NaN            NaN
# homeless_family_households                           NaN             93
# homeless_individuals                                 NaN            696
# homeless_parenting_youth_age_18_24                   NaN            NaN
# homeless_parenting_youth_under_18                    NaN            NaN
# ...

# %%
[n for n in df.coc_name if 'diego' in str(n).lower()]
# Out:
# ['San Diego City and County CoC',
#  'San Diego City and County CoC',
#  'San Diego City and County CoC',
#  'San Diego City and County CoC',
#  'San Diego City and County CoC',
#  'San Diego City and County CoC',
#  'San Diego City and County CoC',
#  'San Diego City and County CoC',
#  'San Diego City and County CoC',
#  'San Diego City and County CoC',
#  'San Diego City and County CoC',
#  'San Diego City and County CoC']

# %%
sd = df[df.coc_name == 'San Diego City and County CoC'].set_index('year')

# %%
sd.homeless_individuals.plot()

# %%
df.homeless_individuals.hist()

# %%
df[df.homeless_individuals < 5000].homeless_individuals.hist()
