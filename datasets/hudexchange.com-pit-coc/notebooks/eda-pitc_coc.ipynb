# %% [markdown]
# # Exploratory Data Analysis
#
# When placed in Metapack data package, this notebook will load the package and run a variety of common EDA operations on the first resource.

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')

# %%
pkg = mp.jupyter.open_package()

# For testing and development
#pkg = mp.open_package('http://s3.amazonaws.com/library.metatab.org/cde.ca.gov-accountability_dashboard-2.zip')

pkg
# Out:
# # HUD Point in Time Counts by CoC
# `hudexchange.com-pit-coc-1` Last Update: 2019-07-07T17:53:00
#
# __
#
#
# ## Documentation Links
#
# * [PIT and HIC Data Since 2007](https://www.hudexchange.info/resource/3031/pit-and-hic-data-since-2007/)
#
#
#
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
# ## Resources
#
# * ** [pitc_coc](data/pitc_coc.csv)**. Combined pitc, 2007 to 2018
#
# ## References
#
# * **[pitc_coc_2018](https://www.hudexchange.info/resources/documents/2007-2018-PIT-Counts-by-CoC.xlsx#2018)**. 2007 - 2018 PIT Counts by CoC; 2018 workbook
# * **[pitc_coc_2017](https://www.hudexchange.info/resources/documents/2007-2018-PIT-Counts-by-CoC.xlsx#2017)**. 2006 - 2018 PIT Counts by CoC; 2017 workbook
# * **[pitc_coc_2016](https://www.hudexchange.info/resources/documents/2007-2018-PIT-Counts-by-CoC.xlsx#2016)**. 2005 - 2018 PIT Counts by CoC; 2016 workbook
# * **[pitc_coc_2015](https://www.hudexchange.info/resources/documents/2007-2018-PIT-Counts-by-CoC.xlsx#2015)**. 2004 - 2018 PIT Counts by CoC; 2015 workbook
# * **[pitc_coc_2014](https://www.hudexchange.info/resources/documents/2007-2018-PIT-Counts-by-CoC.xlsx#2014)**. 2003 - 2018 PIT Counts by CoC; 2014 workbook
# * **[pitc_coc_2013](https://www.hudexchange.info/resources/documents/2007-2018-PIT-Counts-by-CoC.xlsx#2013)**. 2002 - 2018 PIT Counts by CoC; 2013 workbook
# * **[pitc_coc_2012](https://www.hudexchange.info/resources/documents/2007-2018-PIT-Counts-by-CoC.xlsx#2012)**. 2001 - 2018 PIT Counts by CoC; 2012 workbook
# * **[pitc_coc_2011](https://www.hudexchange.info/resources/documents/2007-2018-PIT-Counts-by-CoC.xlsx#2011)**. 2000 - 2018 PIT Counts by CoC; 2011 workbook
# * **[pitc_coc_2010](https://www.hudexchange.info/resources/documents/2007-2018-PIT-Counts-by-CoC.xlsx#2010)**. 1999 - 2018 PIT Counts by CoC; 2010 workbook
# * **[pitc_coc_2009](https://www.hudexchange.info/resources/documents/2007-2018-PIT-Counts-by-CoC.xlsx#2009)**. 1998 - 2018 PIT Counts by CoC; 2009 workbook
# * **[pitc_coc_2008](https://www.hudexchange.info/resources/documents/2007-2018-PIT-Counts-by-CoC.xlsx#2008)**. 1997 - 2018 PIT Counts by CoC; 2008 workbook
# * **[pitc_coc_2007](https://www.hudexchange.info/resources/documents/2007-2018-PIT-Counts-by-CoC.xlsx#2007)**. 1996 - 2018 PIT Counts by CoC; 2007 workbook

# %%
resource_name='pitc_coc'

# %%
pkg.resource(resource_name)
# Out:
# <Resource: metadata.csv 40:1 root.datafile data/pitc_coc.csv ['pitc_coc', 'Combined pitc, 2007 to 2018', '', '']>

# %%
df = pkg.resource(resource_name).read_csv(parse_dates=True)

# %%
df.head()
# Out:
#    year coc_category                                           coc_name  \
# 0  2007          NaN                                              Total
# 1  2007          NaN                                                NaN
# 2  2007       AK-500                                      Anchorage CoC
# 3  2007       AK-501                        Alaska Balance of State CoC
# 4  2007       AL-500  Birmingham/Jefferson, St. Clair, Shelby Counti...
#
#   coc_number  chronically_homeless  chronically_homeless_individuals  \
# 0        NaN                   NaN                          119813.0
# 1        NaN                   NaN                               NaN
# 2        NaN                   NaN                             224.0
# 3        NaN                   NaN                              54.0
# 4        NaN                   NaN                             516.0
#
#    chronically_homeless_people_in_families  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    homeless_children_of_parenting_youth  homeless_family_households  \
# 0                                   NaN                     78535.0
# 1                                   NaN                         NaN
# 2                                   NaN                        93.0
# 3                                   NaN                        97.0
# 4                                   NaN                       228.0
#
#    homeless_individuals  ...  unsheltered_homeless_family_households  \
# 0              412700.0  ...                                 17721.0
# 1                   NaN  ...                                     NaN
# 2                 696.0  ...                                     8.0
# 3                 366.0  ...                                    17.0
# 4                1529.0  ...                                    75.0
#
#    unsheltered_homeless_individuals  \
# 0                          199627.0
# 1                               NaN
# 2                             107.0
# 3                              64.0
# 4                             696.0
#
#    unsheltered_homeless_parenting_youth_age_18_24  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    unsheltered_homeless_parenting_youth_under_18  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    unsheltered_homeless_parenting_youth_under_25  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    unsheltered_homeless_people_in_families  \
# 0                                  56230.0
# 1                                      NaN
# 2                                     25.0
# 3                                     59.0
# 4                                    168.0
#
#    unsheltered_homeless_unaccompanied_youth_age_18_24  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    unsheltered_homeless_unaccompanied_youth_under_18  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    unsheltered_homeless_unaccompanied_youth_under_25  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    unsheltered_homeless_veterans
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
# [5 rows x 84 columns]

# %%
empty_col_names = [cn for cn in df.columns if df[cn].nunique() == 0]
const_col_names= [cn for cn in df.columns if df[cn].nunique() == 1]
ignore_cols = empty_col_names+const_col_names
dt_col_names= list(df.select_dtypes(include=[np.datetime64]).columns)

number_col_names = [ cn for cn in df.select_dtypes(include=[np.number]).columns if cn not in ignore_cols ]
other_col_names = [cn for cn in df.columns if cn not in (empty_col_names+const_col_names+dt_col_names+number_col_names)]

# %%
pd.DataFrame.from_dict({'empty':[len(empty_col_names)], 
                        'const':[len(const_col_names)],
                        'datetime':[len(dt_col_names)],
                        'number':[len(number_col_names)],
                        'other':[len(other_col_names)],
                       }, 
                       orient='index', columns=['count'])
# Out:
#           count
# empty         0
# const         0
# datetime      0
# number       81
# other         3

# %% [markdown]
# # Constant Columns

# %%
if const_col_names:
    display(df[const_col_names].drop_duplicates().T)

# %% [markdown]
# # Empty Columns

# %%
if empty_col_names:
    display(df[empty_col_names].drop_duplicates().T)

# %% [markdown]
# # Date and Time Columns

# %%
if dt_col_names:
    display(df[dt_col_names].info())
    display(df[dt_col_names].describe().T)

# %% [markdown]
# # Number Columns

# %%
if number_col_names:
    display(df[number_col_names].info())
    display(df[number_col_names].describe().T)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4770 entries, 0 to 4769
# Data columns (total 81 columns):
# year                                                       4770 non-null int64
# chronically_homeless                                       3162 non-null float64
# chronically_homeless_individuals                           4736 non-null float64
# chronically_homeless_people_in_families                    3162 non-null float64
# homeless_children_of_parenting_youth                       1588 non-null float64
# homeless_family_households                                 4736 non-null float64
# homeless_individuals                                       4736 non-null float64
# homeless_parenting_youth_age_18_24                         1588 non-null float64
# homeless_parenting_youth_under_18                          1588 non-null float64
# homeless_parenting_youth_under_25                          1588 non-null float64
# homeless_people_in_families                                4736 non-null float64
# homeless_unaccompanied_youth_age_18_24                     1588 non-null float64
# homeless_unaccompanied_youth_under_18                      1588 non-null float64
# homeless_unaccompanied_youth_under_25                      1588 non-null float64
# homeless_veterans                                          3162 non-null float64
# overall_homeless                                           4736 non-null float64
# sheltered_es_chronically_homeless                          3162 non-null float64
# sheltered_es_chronically_homeless_individuals              3948 non-null float64
# sheltered_es_chronically_homeless_people_in_families       3162 non-null float64
# sheltered_es_homeless                                      4736 non-null float64
# sheltered_es_homeless_children_of_parenting_youth          1588 non-null float64
# sheltered_es_homeless_family_households                    4736 non-null float64
# sheltered_es_homeless_individuals                          4736 non-null float64
# sheltered_es_homeless_parenting_youth_age_18_24            1588 non-null float64
# sheltered_es_homeless_parenting_youth_under_18             1588 non-null float64
# sheltered_es_homeless_parenting_youth_under_25             1588 non-null float64
# sheltered_es_homeless_people_in_families                   4736 non-null float64
# sheltered_es_homeless_unaccompanied_youth_age_18_24        1588 non-null float64
# sheltered_es_homeless_unaccompanied_youth_under_18         1588 non-null float64
# sheltered_es_homeless_unaccompanied_youth_under_25         1588 non-null float64
# sheltered_es_homeless_veterans                             1981 non-null float64
# sheltered_sh_chronically_homeless                          3948 non-null float64
# sheltered_sh_chronically_homeless_individuals              3948 non-null float64
# sheltered_sh_homeless                                      4736 non-null float64
# sheltered_sh_homeless_individuals                          4736 non-null float64
# sheltered_sh_homeless_unaccompanied_youth_age_18_24        1588 non-null float64
# sheltered_sh_homeless_unaccompanied_youth_under_18         1192 non-null float64
# sheltered_sh_homeless_unaccompanied_youth_under_25         1588 non-null float64
# sheltered_sh_homeless_veterans                             1981 non-null float64
# sheltered_th_homeless                                      4736 non-null float64
# sheltered_th_homeless_children_of_parenting_youth          1588 non-null float64
# sheltered_th_homeless_family_households                    4736 non-null float64
# sheltered_th_homeless_individuals                          4736 non-null float64
# sheltered_th_homeless_parenting_youth_age_18_24            1588 non-null float64
# sheltered_th_homeless_parenting_youth_under_18             1588 non-null float64
# sheltered_th_homeless_parenting_youth_under_25             1588 non-null float64
# sheltered_th_homeless_people_in_families                   4736 non-null float64
# sheltered_th_homeless_unaccompanied_youth_age_18_24        1588 non-null float64
# sheltered_th_homeless_unaccompanied_youth_under_18         1588 non-null float64
# sheltered_th_homeless_unaccompanied_youth_under_25         1588 non-null float64
# sheltered_th_homeless_veterans                             1981 non-null float64
# sheltered_total_chronically_homeless                       3162 non-null float64
# sheltered_total_chronically_homeless_individuals           4736 non-null float64
# sheltered_total_chronically_homeless_people_in_families    3162 non-null float64
# sheltered_total_homeless                                   4736 non-null float64
# sheltered_total_homeless_children_of_parenting_youth       1588 non-null float64
# sheltered_total_homeless_family_households                 4736 non-null float64
# sheltered_total_homeless_individuals                       4736 non-null float64
# sheltered_total_homeless_parenting_youth_age_18_24         1588 non-null float64
# sheltered_total_homeless_parenting_youth_under_18          1588 non-null float64
# sheltered_total_homeless_parenting_youth_under_25          1588 non-null float64
# sheltered_total_homeless_people_in_families                4736 non-null float64
# sheltered_total_homeless_unaccompanied_youth_age_18_24     1588 non-null float64
# sheltered_total_homeless_unaccompanied_youth_under_18      1588 non-null float64
# sheltered_total_homeless_unaccompanied_youth_under_25      1588 non-null float64
# sheltered_total_homeless_veterans                          3162 non-null float64
# unsheltered_chronically_homeless                           3162 non-null float64
# unsheltered_chronically_homeless_individuals               4736 non-null float64
# unsheltered_chronically_homeless_people_in_families        3162 non-null float64
# unsheltered_homeless                                       4736 non-null float64
# unsheltered_homeless_children_of_parenting_youth           1588 non-null float64
# unsheltered_homeless_family_households                     4736 non-null float64
# unsheltered_homeless_individuals                           4736 non-null float64
# unsheltered_homeless_parenting_youth_age_18_24             1588 non-null float64
# unsheltered_homeless_parenting_youth_under_18              1588 non-null float64
# unsheltered_homeless_parenting_youth_under_25              1588 non-null float64
# unsheltered_homeless_people_in_families                    4736 non-null float64
# unsheltered_homeless_unaccompanied_youth_age_18_24         1588 non-null float64
# unsheltered_homeless_unaccompanied_youth_under_18          1588 non-null float64
# unsheltered_homeless_unaccompanied_youth_under_25          1588 non-null float64
# unsheltered_homeless_veterans                              3162 non-null float64
# dtypes: float64(80), int64(1)
# memory usage: 2.9 MB
# None
#                                                      count         mean  \
# year                                                4770.0  2012.512998
# chronically_homeless                                3162.0   510.716003
# chronically_homeless_individuals                    4736.0   489.557010
# chronically_homeless_people_in_families             3162.0    64.119545
# homeless_children_of_parenting_youth                1588.0    62.827456
# homeless_family_households                          4736.0   356.773649
# homeless_individuals                                4736.0  1923.675676
# homeless_parenting_youth_age_18_24                  1588.0    47.163728
# homeless_parenting_youth_under_18                   1588.0     0.505038
# homeless_parenting_youth_under_25                   1588.0    47.668766
# homeless_people_in_families                         4736.0  1110.514780
# homeless_unaccompanied_youth_age_18_24              1588.0   163.775819
# homeless_unaccompanied_youth_under_18               1588.0    21.686398
# homeless_unaccompanied_youth_under_25               1588.0   185.462217
# homeless_veterans                                   3162.0   250.750158
# overall_homeless                                    4736.0  3034.190456
# sheltered_es_chronically_homeless                   3162.0   183.688805
# sheltered_es_chronically_homeless_individuals       3948.0   162.605370
# sheltered_es_chronically_homeless_people_in_fam...  3162.0    36.273245
# sheltered_es_homeless                               4736.0  1209.730997
# sheltered_es_homeless_children_of_parenting_youth   1588.0    37.589421
# sheltered_es_homeless_family_households             4736.0   171.439611
# sheltered_es_homeless_individuals                   4736.0   670.150338
# sheltered_es_homeless_parenting_youth_age_18_24     1588.0    28.906801
# sheltered_es_homeless_parenting_youth_under_18      1588.0     0.152393
# sheltered_es_homeless_parenting_youth_under_25      1588.0    29.059194
# sheltered_es_homeless_people_in_families            4736.0   539.580659
# sheltered_es_homeless_unaccompanied_youth_age_1...  1588.0    50.439547
# sheltered_es_homeless_unaccompanied_youth_under_18  1588.0     7.928212
# sheltered_es_homeless_unaccompanied_youth_under_25  1588.0    58.367758
# ...                                                    ...          ...
# sheltered_total_chronically_homeless                3162.0   189.703352
# sheltered_total_chronically_homeless_individuals    4736.0   176.807432
# sheltered_total_chronically_homeless_people_in_...  3162.0    36.273245
# sheltered_total_homeless                            4736.0  1962.446791
# sheltered_total_homeless_children_of_parenting_...  1588.0    59.885390
# sheltered_total_homeless_family_households          4736.0   297.380912
# sheltered_total_homeless_individuals                4736.0  1036.535895
# sheltered_total_homeless_parenting_youth_age_18_24  1588.0    44.803526
# sheltered_total_homeless_parenting_youth_under_18   1588.0     0.463476
# sheltered_total_homeless_parenting_youth_under_25   1588.0    45.267003
# sheltered_total_homeless_people_in_families         4736.0   925.910895
# sheltered_total_homeless_unaccompanied_youth_ag...  1588.0    84.304786
# sheltered_total_homeless_unaccompanied_youth_un...  1588.0    10.882872
# sheltered_total_homeless_unaccompanied_youth_un...  1588.0    95.187657
# sheltered_total_homeless_veterans                   3162.0   156.935484
# unsheltered_chronically_homeless                    3162.0   321.012650
# unsheltered_chronically_homeless_individuals        4736.0   312.749578
# unsheltered_chronically_homeless_people_in_fami...  3162.0    27.846300
# unsheltered_homeless                                4736.0  1071.743666
# unsheltered_homeless_children_of_parenting_youth    1588.0     2.942065
# unsheltered_homeless_family_households              4736.0    59.392736
# unsheltered_homeless_individuals                    4736.0   887.139780
# unsheltered_homeless_parenting_youth_age_18_24      1588.0     2.360202
# unsheltered_homeless_parenting_youth_under_18       1588.0     0.041562
# unsheltered_homeless_parenting_youth_under_25       1588.0     2.401763
# unsheltered_homeless_people_in_families             4736.0   184.603885
# unsheltered_homeless_unaccompanied_youth_age_18_24  1588.0    79.471033
# unsheltered_homeless_unaccompanied_youth_under_18   1588.0    10.803526
# unsheltered_homeless_unaccompanied_youth_under_25   1588.0    90.274559
# unsheltered_homeless_veterans                       3162.0    93.814674
#
#                                                              std     min  \
# year                                                    3.455911  2007.0
# chronically_homeless                                 5133.710931     0.0
# chronically_homeless_individuals                     4948.660105     0.0
# chronically_homeless_people_in_families               668.153822     0.0
# homeless_children_of_parenting_youth                  641.140095     0.0
# homeless_family_households                           3609.347084     0.0
# homeless_individuals                                19212.144274     0.0
# homeless_parenting_youth_age_18_24                    484.327392     0.0
# homeless_parenting_youth_under_18                       5.178415     0.0
# homeless_parenting_youth_under_25                     489.208546     0.0
# homeless_people_in_families                         11227.294819     0.0
# homeless_unaccompanied_youth_age_18_24               1640.964663     0.0
# homeless_unaccompanied_youth_under_18                 219.430143     0.0
# homeless_unaccompanied_youth_under_25                1857.938954     0.0
# homeless_veterans                                    2547.913459     0.0
# overall_homeless                                    30358.568768     4.0
# sheltered_es_chronically_homeless                    1846.009231     0.0
# sheltered_es_chronically_homeless_individuals        1655.499225     0.0
# sheltered_es_chronically_homeless_people_in_fam...    375.602716     0.0
# sheltered_es_homeless                               12338.321664     0.0
# sheltered_es_homeless_children_of_parenting_youth     396.787889     0.0
# sheltered_es_homeless_family_households              1795.482249     0.0
# sheltered_es_homeless_individuals                    6718.798072     0.0
# sheltered_es_homeless_parenting_youth_age_18_24       309.694406     0.0
# sheltered_es_homeless_parenting_youth_under_18          1.666437     0.0
# sheltered_es_homeless_parenting_youth_under_25        311.105611     0.0
# sheltered_es_homeless_people_in_families             5687.540293     0.0
# sheltered_es_homeless_unaccompanied_youth_age_1...    506.343255     0.0
# sheltered_es_homeless_unaccompanied_youth_under_18     79.090107     0.0
# sheltered_es_homeless_unaccompanied_youth_under_25    584.491248     0.0
# ...                                                          ...     ...
# sheltered_total_chronically_homeless                 1906.263384     0.0
# sheltered_total_chronically_homeless_individuals     1796.878322     0.0
# sheltered_total_chronically_homeless_people_in_...    375.602716     0.0
# sheltered_total_homeless                            19697.852110     0.0
# sheltered_total_homeless_children_of_parenting_...    612.590536     0.0
# sheltered_total_homeless_family_households           3009.801746     0.0
# sheltered_total_homeless_individuals                10344.814684     0.0
# sheltered_total_homeless_parenting_youth_age_18_24    461.662912     0.0
# sheltered_total_homeless_parenting_youth_under_18       4.775679     0.0
# sheltered_total_homeless_parenting_youth_under_25     466.138153     0.0
# sheltered_total_homeless_people_in_families          9384.695838     0.0
# sheltered_total_homeless_unaccompanied_youth_ag...    843.875428     0.0
# sheltered_total_homeless_unaccompanied_youth_un...    108.599686     0.0
# sheltered_total_homeless_unaccompanied_youth_un...    951.647979     0.0
# sheltered_total_homeless_veterans                    1587.445739     0.0
# unsheltered_chronically_homeless                     3250.106346     0.0
# unsheltered_chronically_homeless_individuals         3180.812911     0.0
# unsheltered_chronically_homeless_people_in_fami...    311.625350     0.0
# unsheltered_homeless                                10846.310030     0.0
# unsheltered_homeless_children_of_parenting_youth       29.679433     0.0
# unsheltered_homeless_family_households                654.121316     0.0
# unsheltered_homeless_individuals                     8952.022268     0.0
# unsheltered_homeless_parenting_youth_age_18_24         23.779071     0.0
# unsheltered_homeless_parenting_youth_under_18           0.502832     0.0
# unsheltered_homeless_parenting_youth_under_25          24.184854     0.0
# unsheltered_homeless_people_in_families              2020.149176     0.0
# unsheltered_homeless_unaccompanied_youth_age_18_24    806.142107     0.0
# unsheltered_homeless_unaccompanied_youth_under_18     114.331031     0.0
# unsheltered_homeless_unaccompanied_youth_under_25     916.923600     0.0
# unsheltered_homeless_veterans                         970.819283     0.0
#
#                                                         25%     50%      75%  \
# year                                                2010.00  2013.0  2016.00
# chronically_homeless                                  37.00    90.0   227.00
# chronically_homeless_individuals                      34.00    85.0   218.00
# chronically_homeless_people_in_families                0.00     7.0    24.00
# homeless_children_of_parenting_youth                   4.00    11.0    25.25
# homeless_family_households                            36.00    72.0   159.00
# homeless_individuals                                 189.00   411.5   925.25
# homeless_parenting_youth_age_18_24                     3.00     8.0    18.00
# homeless_parenting_youth_under_18                      0.00     0.0     0.00
# homeless_parenting_youth_under_25                      3.00     8.0    19.00
# homeless_people_in_families                          108.00   219.0   493.00
# homeless_unaccompanied_youth_age_18_24                13.00    30.0    73.00
# homeless_unaccompanied_youth_under_18                  0.00     2.0    10.00
# homeless_unaccompanied_youth_under_25                 15.00    36.0    84.00
# homeless_veterans                                     17.00    51.0   136.00
# overall_homeless                                     321.00   665.0  1475.25
# sheltered_es_chronically_homeless                     15.00    40.0    94.00
# sheltered_es_chronically_homeless_individuals         12.00    36.0    86.00
# sheltered_es_chronically_homeless_people_in_fam...     0.00     4.0    14.00
# sheltered_es_homeless                                119.00   247.0   540.50
# sheltered_es_homeless_children_of_parenting_youth      1.00     5.0    12.00
# sheltered_es_homeless_family_households               13.00    27.0    61.00
# sheltered_es_homeless_individuals                     71.00   153.0   352.00
# sheltered_es_homeless_parenting_youth_age_18_24        1.00     3.0     9.00
# sheltered_es_homeless_parenting_youth_under_18         0.00     0.0     0.00
# sheltered_es_homeless_parenting_youth_under_25         1.00     3.0     9.00
# sheltered_es_homeless_people_in_families              39.00    84.0   185.00
# sheltered_es_homeless_unaccompanied_youth_age_1...     5.00    11.0    27.00
# sheltered_es_homeless_unaccompanied_youth_under_18     0.00     1.0     5.00
# sheltered_es_homeless_unaccompanied_youth_under_25     6.00    14.0    32.00
# ...                                                     ...     ...      ...
# sheltered_total_chronically_homeless                  15.00    42.0    97.00
# sheltered_total_chronically_homeless_individuals      14.00    38.5    93.00
# sheltered_total_chronically_homeless_people_in_...     0.00     4.0    14.00
# sheltered_total_homeless                             219.75   434.0   955.25
# sheltered_total_homeless_children_of_parenting_...     3.00    10.0    23.00
# sheltered_total_homeless_family_households            29.00    57.0   129.00
# sheltered_total_homeless_individuals                 118.00   243.0   550.00
# sheltered_total_homeless_parenting_youth_age_18_24     2.00     7.0    17.00
# sheltered_total_homeless_parenting_youth_under_18      0.00     0.0     0.00
# sheltered_total_homeless_parenting_youth_under_25      2.00     7.0    17.00
# sheltered_total_homeless_people_in_families           88.00   175.0   394.00
# sheltered_total_homeless_unaccompanied_youth_ag...     9.00    20.0    44.25
# sheltered_total_homeless_unaccompanied_youth_un...     0.00     1.0     8.00
# sheltered_total_homeless_unaccompanied_youth_un...    10.00    24.0    52.00
# sheltered_total_homeless_veterans                     10.00    33.0    91.00
# unsheltered_chronically_homeless                       9.00    32.0   119.00
# unsheltered_chronically_homeless_individuals           9.00    32.0   112.00
# unsheltered_chronically_homeless_people_in_fami...     0.00     0.0     5.00
# unsheltered_homeless                                  38.00   117.0   426.00
# unsheltered_homeless_children_of_parenting_youth       0.00     0.0     1.00
# unsheltered_homeless_family_households                 0.00     2.0    15.00
# unsheltered_homeless_individuals                      31.00    99.0   339.00
# unsheltered_homeless_parenting_youth_age_18_24         0.00     0.0     1.00
# unsheltered_homeless_parenting_youth_under_18          0.00     0.0     0.00
# unsheltered_homeless_parenting_youth_under_25          0.00     0.0     1.00
# unsheltered_homeless_people_in_families                0.00     7.0    45.00
# unsheltered_homeless_unaccompanied_youth_age_18_24     1.00     6.0    23.00
# unsheltered_homeless_unaccompanied_youth_under_18      0.00     0.0     1.00
# unsheltered_homeless_unaccompanied_youth_under_25      1.00     6.0    25.00
# unsheltered_homeless_veterans                          2.00     8.0    31.00
#
#                                                          max
# year                                                  2018.0
# chronically_homeless                                119033.0
# chronically_homeless_individuals                    120115.0
# chronically_homeless_people_in_families              16539.0
# homeless_children_of_parenting_youth                 13318.0
# homeless_family_households                           79442.0
# homeless_individuals                                412700.0
# homeless_parenting_youth_age_18_24                    9800.0
# homeless_parenting_youth_under_18                      126.0
# homeless_parenting_youth_under_25                     9901.0
# homeless_people_in_families                         241937.0
# homeless_unaccompanied_youth_age_18_24               33668.0
# homeless_unaccompanied_youth_under_18                 4667.0
# homeless_unaccompanied_youth_under_25                38303.0
# homeless_veterans                                    65455.0
# overall_homeless                                    647258.0
# sheltered_es_chronically_homeless                    44834.0
# sheltered_es_chronically_homeless_individuals        45592.0
# sheltered_es_chronically_homeless_people_in_fam...    9362.0
# sheltered_es_homeless                               275705.0
# sheltered_es_homeless_children_of_parenting_youth     7679.0
# sheltered_es_homeless_family_households              39588.0
# sheltered_es_homeless_individuals                   148764.0
# sheltered_es_homeless_parenting_youth_age_18_24       5868.0
# sheltered_es_homeless_parenting_youth_under_18          41.0
# sheltered_es_homeless_parenting_youth_under_25        5892.0
# sheltered_es_homeless_people_in_families            126941.0
# sheltered_es_homeless_unaccompanied_youth_age_1...   10388.0
# sheltered_es_homeless_unaccompanied_youth_under_18    1627.0
# sheltered_es_homeless_unaccompanied_youth_under_25   11963.0
# ...                                                      ...
# sheltered_total_chronically_homeless                 46169.0
# sheltered_total_chronically_homeless_individuals     45592.0
# sheltered_total_chronically_homeless_people_in_...    9362.0
# sheltered_total_homeless                            403543.0
# sheltered_total_homeless_children_of_parenting_...   12669.0
# sheltered_total_homeless_family_households           62305.0
# sheltered_total_homeless_individuals                215995.0
# sheltered_total_homeless_parenting_youth_age_18_24    9344.0
# sheltered_total_homeless_parenting_youth_under_18      118.0
# sheltered_total_homeless_parenting_youth_under_25     9462.0
# sheltered_total_homeless_people_in_families         191903.0
# sheltered_total_homeless_unaccompanied_youth_ag...   17551.0
# sheltered_total_homeless_unaccompanied_youth_un...    2287.0
# sheltered_total_homeless_unaccompanied_youth_un...   19838.0
# sheltered_total_homeless_veterans                    40033.0
# unsheltered_chronically_homeless                     72864.0
# unsheltered_chronically_homeless_individuals         78045.0
# unsheltered_chronically_homeless_people_in_fami...    8856.0
# unsheltered_homeless                                255857.0
# unsheltered_homeless_children_of_parenting_youth       662.0
# unsheltered_homeless_family_households               17721.0
# unsheltered_homeless_individuals                    199670.0
# unsheltered_homeless_parenting_youth_age_18_24         518.0
# unsheltered_homeless_parenting_youth_under_18           13.0
# unsheltered_homeless_parenting_youth_under_25          520.0
# unsheltered_homeless_people_in_families              56230.0
# unsheltered_homeless_unaccompanied_youth_age_18_24   17248.0
# unsheltered_homeless_unaccompanied_youth_under_18     2513.0
# unsheltered_homeless_unaccompanied_youth_under_25    19761.0
# unsheltered_homeless_veterans                        25436.0
#
# [81 rows x 8 columns]

# %% [markdown]
# ## Distributions

# %%
def plot_histograms(df):

    col_names = list(df.columns)

    n_cols = np.ceil(np.sqrt(len(col_names)))
    n_rows = np.ceil(np.sqrt(len(col_names)))

    #plt.figure(figsize=(3*n_cols,3*n_rows))
    fig, ax = plt.subplots(figsize=(3*n_cols,3*n_rows))
    
    for i in range(0,len(col_names)):
        plt.subplot(n_rows + 1,n_cols,i+1)
        try:
            g = sns.distplot(df[col_names[i]].dropna(),kde=True) 
            g.set(xticklabels=[])
            g.set(yticklabels=[])
        except:
            pass
        
    plt.tight_layout()

# %%
plot_histograms(df[number_col_names])
# Out:
# /Users/eric/anaconda3/envs/metatab-dev/lib/python3.7/site-packages/ipykernel_launcher.py:20: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations

# %% [markdown]
# ## Box Plots

# %%
def plot_boxes(df):

    col_names = list(df.columns)

    n_cols = np.ceil(np.sqrt(len(col_names)))
    n_rows = np.ceil(np.sqrt(len(col_names)))

    #plt.figure(figsize=(2*n_cols,3*n_rows))
    fig, ax = plt.subplots(figsize=(2*n_cols,5*n_rows))
    
    for i in range(0,len(col_names)):
        plt.subplot(n_rows + 1,n_cols,i+1)
        try:
            g = sns.boxplot(df[col_names[i]].dropna(),orient='v') 
        except:
            pass
        
    plt.tight_layout()

# %%
  
plot_boxes(df[number_col_names])

# %%
## Correlations

# %%
cm = df[number_col_names].corr()

mask = np.zeros_like(cm, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(.5*len(number_col_names),.5*len(number_col_names)))
sns.heatmap(cm, mask=mask, cmap = 'viridis')

# %% [markdown]
# # Other Columns

# %%
if other_col_names:
    display(df[other_col_names].info())
    display(df[other_col_names].describe().T)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4770 entries, 0 to 4769
# Data columns (total 3 columns):
# coc_category    4746 non-null object
# coc_name        4746 non-null object
# coc_number      398 non-null object
# dtypes: object(3)
# memory usage: 111.9+ KB
# None
#              count unique                 top freq
# coc_category  4746    410              TN-510   12
# coc_name      4746    410  Virginia Beach CoC   12
# coc_number     398      4       Suburban CoCs  174

# %% [markdown]
# # Nulls

# %%
cols = dt_col_names + number_col_names + other_col_names

fig, ax = plt.subplots(figsize=(15,.5*len(cols)))
sns.heatmap(df[cols].sort_values('year').isnull().T,cbar=False,xticklabels=False,cmap = 'viridis', ax=ax )
